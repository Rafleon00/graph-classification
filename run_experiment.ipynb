# %% [markdown]
# ## Graph Neural Network Classification
#
# ### Objective:
# Build a model that train and predicts based on Cora dataset

# %% [markdown]
# ### 1. Install dependencies

# %%
from google.colab import drive
drive.mount('/content/drive')

# Move to the folder directory 
# %cd drive/MyDrive/'Colab Notebooks'/Ruben/Graph Classification/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/Ruben/Graph Classification

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 585 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 51 kB 255 kB/s
# ...
#      |████████████████████████████████| 43 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 407 kB 12.8 MB/s
# ...
#      |████████████████████████████████| 596 kB 54.1 MB/s
# ...
#      |████████████████████████████████| 419 kB 61.5 MB/s
# ...
#      |████████████████████████████████| 141 kB 74.7 MB/s
# ...
#   Created wheel for torch-scatter: filename=torch_scatter-2.0.9-cp37-cp37m-linux_x86_64.whl size=3861168 sha256=b28688c5d528b8dd88dfc5f9b0c6b84499d9a9cc267942327a536b4f763763c8
#   Stored in directory: /root/.cache/pip/wheels/dd/57/a3/42ea193b77378ce634eb9454c9bc1e3163f3b482a35cdee4d1
# ...
#   Created wheel for torch-sparse: filename=torch_sparse-0.6.14-cp37-cp37m-linux_x86_64.whl size=1647907 sha256=fe14e0570e3ced778b6cdc96e1cf168286bbcecd19e253378adf0805ab795b2b
# ...

# %% [markdown]
# ### 2. Run run_experiment.py script

# %%
# !python gnn_node_classification.py --max_epochs=200 --hidden_channels=16 --attention_heads=12 --lr=0.001 --dropout=0.5
# Out:
# Global seed set to 10
# Dataset: Cora()
# ...
# Number of graphs: 1
# Number of classes: 7
# Number of features: 1433
# Number of node attributes: 1433
# Number of edge attributes: 0
#
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])
# ...
# Number of nodes: 2708
# Number of edges: 10556
# Number of training nodes: 140
# Number of validation nodes: 500
# Number of testing nodes: 1000
# Has self-loops: False
# Is undirected: True
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type | Params
# -------------------------------
# 0 | model | GNN  | 277 K
# -------------------------------
# 277 K     Trainable params
# 0         Non-trainable params
# 277 K     Total params
# 1.108     Total estimated model params size (MB)
# ...
