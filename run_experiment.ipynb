# %% [markdown]
# ## GNN Task
#
# ### Objective:
# Build a GNN model that performs node classification on Cora Dataset (https://paperswithcode.com/dataset/cora)
#
# ### Important:
# Automatically run on CPU/GPU/TPU depending on environment

# %% [markdown]
# ### 1. Install dependencies
# - Clone repo
# - cd to graph-classification folder
# - Install requirements

# %%
# !git clone https://github.com/ralvf/graph-classification
# %cd graph-classification
# Out:
# Cloning into 'graph-classification'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 11 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (11/11), done.
# /content/graph-classification

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 585 kB 14.8 MB/s
# ...
#      |████████████████████████████████| 51 kB 245 kB/s
# ...
#      |████████████████████████████████| 43 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 407 kB 57.4 MB/s
# ...
#      |████████████████████████████████| 419 kB 61.3 MB/s
# ...
#      |████████████████████████████████| 141 kB 63.9 MB/s
# ...
#      |████████████████████████████████| 596 kB 57.1 MB/s
# ...
#   Created wheel for torch-scatter: filename=torch_scatter-2.0.9-cp37-cp37m-linux_x86_64.whl size=3567072 sha256=38050f6eed55e4511942f6955917e1b8f880d937b07015b8cf3547b628b46dff
#   Stored in directory: /root/.cache/pip/wheels/dd/57/a3/42ea193b77378ce634eb9454c9bc1e3163f3b482a35cdee4d1
# ...
#   Created wheel for torch-sparse: filename=torch_sparse-0.6.14-cp37-cp37m-linux_x86_64.whl size=1703245 sha256=1fbcb08c5b896d57c992b8f1acbc7a7bf924a06dd333c05c6eec4f6eed22bbc6
# ...

# %% [markdown]
# ### 2. Run gnn_node_classification.py

# %%
# !python gnn_node_classification.py --max_epochs=200 --hidden_channels=16 --attention_heads=12 --lr=0.001
# Out:
# Global seed set to 10
# ...
# Processing...
# Done!
# Dataset: Cora()
# ...
# Number of graphs: 1
# Number of classes: 7
# Number of features: 1433
# Number of node attributes: 1433
# Number of edge attributes: 0
#
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])
# ...
# Number of nodes: 2708
# Number of edges: 10556
# Number of training nodes: 140
# Number of validation nodes: 500
# Number of testing nodes: 1000
# Has self-loops: False
# Is undirected: True
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: logs/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type | Params
# -------------------------------
# 0 | model | GNN  | 277 K
# -------------------------------
# 277 K     Trainable params
# 0         Non-trainable params
# 277 K     Total params
# ...
